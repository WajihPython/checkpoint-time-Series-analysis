# %%
import pandas as pd
series = pd.read_csv('AirPassengers.csv',header=0, parse_dates=[0],  index_col=0)
series
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121
# ...                 ...
# 1960-08-01          606
# 1960-09-01          508
# 1960-10-01          461
# 1960-11-01          390
# 1960-12-01          432
#
# [144 rows x 1 columns]

# %%
series.head(20)
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121
# 1949-06-01          135
# 1949-07-01          148
# 1949-08-01          148
# 1949-09-01          136
# 1949-10-01          119
# 1949-11-01          104
# 1949-12-01          118
# 1950-01-01          115
# 1950-02-01          126
# 1950-03-01          141
# 1950-04-01          135
# 1950-05-01          125
# 1950-06-01          149
# 1950-07-01          170
# 1950-08-01          170

# %%
print(series.size)
# Out:
# 144

# %%
print(series['1949'])
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121
# 1949-06-01          135
# 1949-07-01          148
# 1949-08-01          148
# 1949-09-01          136
# 1949-10-01          119
# 1949-11-01          104
# 1949-12-01          118
# C:\Users\pc\AppData\Local\Temp\ipykernel_22348\1131492188.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   print(series['1949'])

# %%
series.describe()
# Out:
#        #Passengers
# count   144.000000
# mean    280.298611
# std     119.966317
# min     104.000000
# 25%     180.000000
# 50%     265.500000
# 75%     360.500000
# max     622.000000

# %%
from matplotlib import pyplot
pyplot.plot(series)  
pyplot.show()

# %%
import matplotlib.pyplot as plt
def plot_timeseries(df, x, y, title="", xlabel='Month', ylabel='Passengers', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_timeseries(series, x=series.index, y=series['#Passengers'], title='Passengers per month')
